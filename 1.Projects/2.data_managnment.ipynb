# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('D:\DA_Portfolio\Global Condom Sales and Awareness (2015-2025)\Dataset\Rich_Global_Condom_Usage_Dataset.csv')
df['Year'] = pd.to_datetime(df['Year'], errors='coerce', format='%Y')  
df['Year'] = df['Year'].dt.year


df['Male Purchases (%)'] = pd.to_numeric(df['Male Purchases (%)'], errors='coerce')
df['Female Purchases (%)'] = pd.to_numeric(df['Female Purchases (%)'], errors='coerce')
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# <>:6: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\aungh\AppData\Local\Temp\ipykernel_22992\953586648.py:6: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv('D:\DA_Portfolio\Global Condom Sales and Awareness (2015-2025)\Dataset\Rich_Global_Condom_Usage_Dataset.csv')
# C:\Users\aungh\AppData\Local\Temp\ipykernel_22992\953586648.py:6: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv('D:\DA_Portfolio\Global Condom Sales and Awareness (2015-2025)\Dataset\Rich_Global_Condom_Usage_Dataset.csv')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Anaconda3\envs\GCS\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Male Purchases (%)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 11
#       7 df['Year'] = pd.to_datetime(df['Year'], errors='coerce', format='%Y')
#       8 df['Year'] = df['Year'].dt.year
# ---> 11 df['Male Purchases (%)'] = pd.to_numeric(df['Male Purchases (%)'], errors='coerce')
#      12 df['Female Purchases (%)'] = pd.to_numeric(df['Female Purchases (%)'], errors='coerce')
#
# File d:\Anaconda3\envs\GCS\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File d:\Anaconda3\envs\GCS\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Male Purchases (%)'

# %% [markdown]
# Separating male and female purchases into two columns.

# %%
df[['Male Purchases (%)', 'Female Purchases (%)']] = df['Male vs Female Purchases (%)'].str.extract(r'(\d+)% Male - (\d+)% Female')

# %%
df.drop(columns='Male vs Female Purchases (%)')
# Out:
#      Year    Country  Total Sales (Million Units)  \
# 0    2015        USA                          378
# 1    2015        USA                         1875
# 2    2015        USA                         2496
# 3    2015        USA                         1437
# 4    2015        USA                         1923
# ..    ...        ...                          ...
# 545  2025  Australia                          585
# 546  2025  Australia                          273
# 547  2025  Australia                          994
# 548  2025  Australia                          730
# 549  2025  Australia                         1456
#
#      Market Revenue (Million USD) Government Campaigns  \
# 0                      276.304977                   No
# 1                     3002.379846                   No
# 2                     6564.222333                  Yes
# 3                     4993.892125                  Yes
# 4                     5355.152313                  Yes
# ..                            ...                  ...
# 545                    876.695845                   No
# 546                    311.965966                  Yes
# 547                   2787.762423                  Yes
# 548                    938.731002                  Yes
# 549                   2914.958450                  Yes
#
#      Awareness Index (0-10) Most Popular Condom Type  \
# 0                      2.93                    Latex
# 1                      9.28               Ultra-Thin
# 2                      5.26                Non-Latex
# 3                      3.63                Non-Latex
# 4                      5.71                Non-Latex
# ..                      ...                      ...
# 545                    5.53                 Textured
# 546                    3.43                 Textured
# 547                    5.52                 Textured
# 548                    6.73               Ultra-Thin
# 549                    4.03                 Textured
#
#      Contraceptive Usage Rate (%)  Teen Pregnancy Rate (per 1000 teens)  \
# 0                           27.10                                 58.37
# 1                           63.97                                 50.63
# 2                           56.21                                 42.23
# 3                           89.71                                 55.86
# 4                           86.96                                  7.82
# ..                            ...                                   ...
# 545                         77.79                                 52.35
# 546                         48.71                                 32.15
# 547                         57.73                                 63.18
# 548                         30.33                                 32.88
# 549                         47.37                                  5.06
#
#      HIV Prevention Awareness (%)  Online Sales (%)  \
# 0                           89.17             45.00
# 1                           69.25             57.10
# 2                           56.13             59.52
# 3                           78.36             56.83
# 4                           37.61             47.99
# ..                            ...               ...
# 545                         89.26             20.34
# 546                         85.71             15.77
# 547                         33.34             18.98
# 548                         61.39             16.43
# 549                         70.48             55.14
#
#      Average Price per Condom (USD) Brand Dominance  \
# 0                              1.34       Kamasutra
# 1                              2.43            Skyn
# 2                              2.30            Skyn
# 3                              2.48        Manforce
# 4                              0.34          Trojan
# ..                              ...             ...
# 545                            0.48      LifeStyles
# 546                            1.96      LifeStyles
# 547                            1.10           Durex
# 548                            0.87            Skyn
# 549                            0.50       Kamasutra
#
#     Sex Education Programs (Yes/No) Male Purchases (%) Female Purchases (%)
# 0                                No                 69                   39
# 1                                No                 50                   33
# 2                               Yes                 46                   54
# 3                                No                 49                   57
# 4                               Yes                 40                   29
# ..                              ...                ...                  ...
# 545                             Yes                 52                   60
# 546                              No                 62                   41
# 547                             Yes                 45                   59
# 548                             Yes                 72                   31
# 549                              No                 40                   47
#
# [550 rows x 16 columns]

# %%
# Renaming the column
df.rename(columns={'Teen Pregnancy Rate (per 1000 teens)': 'Teen Pregnancy Rate (per 10000 teens)'}, inplace=True)
